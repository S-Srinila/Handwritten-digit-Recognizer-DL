# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
(x_train , y_train),(y_test, x_test) = mnist.load_data()

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000,)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %% [markdown]
# Data Preprocessing

# %%
# reshape and normalize
x_train = x_train.reshape((60000, 28, 28, 1)) / 255.0
x_test = x_test.reshape((10000, 28, 28, 1)) / 255.0

# %%
# one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# Build the NN

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),   #convert 2D imagr to 1D vector
    Dense(128, activation ='relu'),  #hidden layer 1
    Dense(64, activation ='relu'),  #hidden layer 2
    Dense(10, activation='softmax')  #output layer 10 classes
])
# Out:
# C:\Users\srine\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Compile the model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split= 0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9261 - loss: 0.2554 - val_accuracy: 0.9645 - val_loss: 0.1230
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9672 - loss: 0.1082 - val_accuracy: 0.9748 - val_loss: 0.0932
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9778 - loss: 0.0733 - val_accuracy: 0.9733 - val_loss: 0.0915
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9822 - loss: 0.0567 - val_accuracy: 0.9777 - val_loss: 0.0849
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9860 - loss: 0.0442 - val_accuracy: 0.9753 - val_loss: 0.0882
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9886 - loss: 0.0356 - val_accuracy: 0.9762 - val_loss: 0.0872
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.9901 - loss: 0.0303 - val_accuracy: 0.9775 - val_loss: 0.0897
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9910 - loss: 0.0261 - val_accuracy: 0.9787 - val_loss: 0.0885
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9922 - loss: 0.0226 - val_accuracy: 0.9758 - val_loss: 0.1119
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9934 - loss: 0.0197 - val_accuracy: 0.9755 - val_loss: 0.1109

# %% [markdown]
# Evaluate the model

# %%
test_loss, test_accuracy =model.evaluate(x_test, y_test)
print('Test accuracy:', test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9755 - loss: 0.0950
# Test accuracy: 0.9754999876022339

# %%
#predict the new sample
import numpy as np

index = 100   # try any image index
sample = x_test[index].reshape(1, 28, 28)
prediction = model.predict(sample)
print("Predicted Digit:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Predicted Digit: 6
